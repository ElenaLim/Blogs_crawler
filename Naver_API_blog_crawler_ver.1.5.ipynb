# %%
import os
import sys
import urllib.request
import json
client_id = " " # 발급받은 id 입력
client_secret = " " # 발급받은 secret 입력 
quote = input("검색어를 입력해주세요.: ") #검색어 입력받기
encText = urllib.parse.quote(quote)
display_num = input("검색 출력결과 갯수를 적어주세요.(최대100, 숫자만 입력): ") #출력할 갯수 입력받기
url = "https://openapi.naver.com/v1/search/blog?query=" + encText +"&display="+display_num# json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

body = response_body.decode('utf-8')
body
# Out:
# 검색어를 입력해주세요.:  상암 맛집
# 검색 출력결과 갯수를 적어주세요.(최대100, 숫자만 입력):  100
# '{\n"lastBuildDate": "Mon, 25 Oct 2021 14:27:38 +0900",\n"total": 43808,\n"start": 1,\n"display": 100,\n"items": [\n{\n"title": "감격했던 <b>상암 맛집</b> 리스트",\n"link": "https:\\/\\/blog.naver.com\\/lovableje?Redirect=Log&logNo=222508972195",\n"description": "며칠 전 남편과 같이 유명한 <b>상암 맛집</b>에 방문했는데요 이베리코돼지고기를 부위별로 즐길 수 있었던... 스시토와 점심: 38,000원 / 저녁 90,000원 주소: 서울 마포구 상암동 12-74 전화번호: ***-****-**** 영업시간: 12... ",\n"bloggername": "쯘이의 꽃같은일상",\n"bloggerlink": "https://blog.naver.com/lovableje",\n"postdate": "20210917"\n\n},\n{\n"title": "눈길가는 <b>상암 맛집</b> 리스트",\n"link": "https:\\/\\/blog.naver.com\\/staror7?Redirect=Log&logNo=222541918499",\n"description": "며칠 전 대학교 동기들과 마포 쪽에 놀러갔다가 유명한 <b>상암 맛집</b>에 다녀왔어요. 무려 12년 간의... 고깃집은 상암동주민센터에서 차로 1분만에 도착했어요. 간판 아래에 반짝거리는 조명들이 쪼르르... ",\n"bloggername": "새로운 일상",\n"bloggerlink": "https://blog.naver.com/staror7",\n"postdate": "20211019"\n\n},\n{\n"title": "흡족했던 <b>상암 맛집</b> 리스트",\n"link": "https:\\/\\/blog.naver.com\\/leeih009?Redirect=Log&logNo=222408692869",\n"description": "며칠 전, 직장동료들과 유명한 <b>상암 맛집</b>에서 점심식사를 했는데요. 푸짐한 구성의 스키야키를 빠른시간 내에 맛볼 수 있어서 흡족했던 곳이랍니다. 1. 옥소반 상암점 런치-스키야키 A세트 11,900원 주소... ",\n"bloggername": "Hyun Lab",\n"bloggerlink": "https://blog.naver.com/leeih009",\n"postdate": "20210626"\n\n},\n{\n"title": "무한흡입 가능한 <b>상암 맛집</b>",\n"link": "https:\\/\\/blog.naver.com\\/zhao0201?Redirect=Log&logNo=222019408054",\n"description": "며칠 전 친구들과 초밥이 먹고 싶어서 <b>상암 맛집</b>에 찾아갔다. 무한리필집이라 배불리 먹을 수 있고... ㅎ 또한 배달의 민족 어플을 통해 집에서도 간단히 먹을 수 있는 <b>상암 맛집</b> 이었는데 특히 바쁜 점심이나... ",\n"bloggername": "아일린\'s 살.림.백.과.사.전",\n"bloggerlink": "https://blog.naver.com/zhao0201",\n"postdate": "20200702"\n\n},\n{\n"title": "행복이 가득한 <b>상암 맛집</b> 모음집",\n"link": "https:\\/\\/blog.naver.com\\/natory77?Redirect=Log&logNo=222098984062",\n"description": "그리고 근처사는 지인들이 알려준 <b>상암 맛집</b> 목록도 알려드릴게요! 1. 상암동 샤브샤브 선향정샤브샤브, 옥소반, 산들, 천하일과 삼겹살 진저피그, 상암일미락, 고기꾼김춘배, 설레임삼겹살 2. 상암동 떡볶이... ",\n"bloggername": "**aka깡의Know your worth**",\n"bloggerlink": "https://blog.naver.com/natory77",\n"postdate": "20200925"\n\n},\n{\n"title": "경이로운 <b>상암 맛집</b> 모음",\n"link": "https:\\/\\/blog.naver.com\\/hyuni9987?Redirect=Log&logNo=222217005651",\n"description": "오랜만에 마포에 갔다가 점심 먹으러 <b>상암 맛집</b>에 다녀왔어요. 한약재로 우려낸 조갈찜을 맛깔스런 수제반찬과 함께 맛보고 입이 다 호강했던 곳이에요. 1. 인기명 상암점 -조갈찜B(3인) 79,000원/샤갈찜A(2인)... ",\n"bloggername": "호두나무가 사는 세상",\n"bloggerlink": "https://blog.naver.com/hyuni9987",\n"postdate": "20210123"\n\n},\n{\n"title": "쫄깃했던 <b>상암 맛집</b>",\n"link": "https:\\/\\/blog.naver.com\\/brightenedu?Redirect=Log&logNo=221766379557",\n"description": "제가 <b>상암 맛집</b> 으로 출동했어요! 저에게는 다소 생소한 6호선 디지털미디어시티역 8, 9번출구를 통해... 상암DMC라는 큰 건물 뒷골목에 있었어요. 직장인분들 많을 것 같은데 점심메뉴뿐 아니라 저녁에 술자리... ",\n"bloggername": "김원장의 탐구생활",\n"bloggerlink": "https://blog.naver.com/brightenedu",\n"postdate": "20200110"\n\n},\n{\n"title": "감탄이 절로 나오는 <b>상암 맛집</b>",\n"link": "https:\\/\\/blog.naver.com\\/daebakyo?Redirect=Log&logNo=222154100950",\n"description": "하이 하이 괴짜 미녀임&gt;.&lt;ㅋㅋㅋ 며칠 전에 친구들이랑 다녀온 <b>상암 맛집</b>에서 진짜 기가 막혔던 삼합을... 서울 마포구 월드컵북로 375 DMC 이안상암1단지 2층 T. 02-6393-6373 영업. 평일 11:30~22:00 평일 B.T 15:00~17:00... ",\n"bloggername": "『 Hello Baby 괴짜미녀 』",\n"bloggerlink": "https://blog.naver.com/daebakyo",\n"postdate": "20201126"\n\n},\n{\n"title": "훌륭했던 <b>상암 맛집</b> 리스트",\n"link": "https:\\/\\/blog.naver.com\\/rostw92?Redirect=Log&logNo=222425036028",\n"description": "저번 주 토요일에 친한 언니와 함께 집 근처인 상암동에 다녀왔다. 저녁도 먹기로 해서 주변의 <b>상암 맛집</b>을 찾아봤다. 그 중에서 우리 눈길을 한 번에 사로 잡은 곳이 있었다. 1. 츄라우미... ",\n"bloggername": "루씨아 나날의 기록",\n"bloggerlink": "https://blog.naver.com/rostw92",\n"postdate": "20210708"\n\n},\n{\n"title": "29,000 코스요리 만족! <b>상암</b> 파스타<b>맛집</b> 인칸토 키친",\n"link": "https:\\/\\/blog.naver.com\\/wise9140?Redirect=Log&logNo=222531769606",\n"description": "#가성비코스요리 #인칸토키친 #<b>상암맛집</b> 안녕하세요 여러분 수냥입니다 :) 맛집 불모지라고 불리는 상암에서 간만에 괜찮은 곳을 발견해서 냉큼 소개하러 왔습니다ㅎㅎ 일단 저는 코스요리를 먹었는데요... ",\n"bloggername": "ROSEBERRY",\n"bloggerlink": "https://blog.naver.com/wise9140",\n"postdate": "20211009"\n\n},\n{\n"title": "<b>상암 맛집</ ...

# %%
# 불필요한 ""(큰따옴표)지워주기
body = body.replace('"','')
#print(body)

#블로그 제목만 뽑기
import re
titles = re.findall('title: (.*?),\nlink', body) #\n은 엔터의 의미
print('<<제목 모음>>')
print(titles)
print('총 제목 수: ',len(titles),'개')#제목갯수확인

#블로그 링크들 추출
links = re.findall('link: (.*?),\ndescription',body)
print('\n<<링크 모음>>')
print(links)
print('총 링크 수: ',len(links),'개')#링크갯수확인
# Out:
# <<제목 모음>>
# ['감격했던 <b>상암 맛집</b> 리스트', '눈길가는 <b>상암 맛집</b> 리스트', '흡족했던 <b>상암 맛집</b> 리스트', '무한흡입 가능한 <b>상암 맛집</b>', '행복이 가득한 <b>상암 맛집</b> 모음집', '경이로운 <b>상암 맛집</b> 모음', '쫄깃했던 <b>상암 맛집</b>', '감탄이 절로 나오는 <b>상암 맛집</b>', '훌륭했던 <b>상암 맛집</b> 리스트', '29,000 코스요리 만족! <b>상암</b> 파스타<b>맛집</b> 인칸토 키친', '<b>상암 맛집</b> 후라토식당! 규카츠가 맛있는 집', '[디엠씨 <b>맛집</b>] <b>상암</b> 참치공방, 주차되고 분위기 좋은곳~~ ^^', '깔끔했던 <b>상암 맛집</b>', '[<b>상암</b>MBC] <b>상암</b>MBC<b>맛집</b>으로 넘모 유명한 신선한 김밥... ', '<b>상암 맛집</b> 월화고기 - 돼지고기 여기가 최고', '<b>상암</b> 카페 추천 : 크로플 <b>맛집</b> 런이트 RUNIT 위치 메뉴 주차', '여전한 <b>상암 맛집</b>', '<b>상암 맛집</b> - 시카노이에', '<b>상암 맛집</b> 소담 가성비 굿 소갈비 + 함흥냉면', '맛깔스러웠던 <b>상암 맛집</b>', '[상암/이베리코] <b>상암 맛집</b> 이베리코 먹을 “시간돼지”?', '<b>상암맛집</b> 아고야 (일본식 스테이크덮밥)', '<b>상암</b>mbc<b>맛집</b> 건강한 로봇김밥 그린', '삼겹살/목살이 생각날땐 <b>상암맛집</b> 월화고기로!', '<b>상암 맛집</b> :: 소담 냉면 갈비 존맛!', "디지털미디어시티역 밥집) 내돈내산 <b>상암 맛집</b> '아고야... ", '<b>상암 맛집</b> 자꾸 생각나 !', '<b>상암 맛집</b> 청진생대구탕', '[<b>
No=222443731923', 'https:\\/\\/blog.naver.com\\/give85?Redirect=Log&logNo=222497302923', 'https:\\/\\/blog.naver.com\\/dmsdud9138?Redirect=Log&logNo=222325913261', 'https:\\/\\/blog.naver.com\\/cynicroman?Redirect=Log&logNo=222005012191', 'https:\\/\\/blog.naver.com\\/hsjh30?Redirect=Log&logNo=222313637817', 'https:\\/\\/blog.naver.com\\/talesoff?Redirect=Log&logNo=222509493083', 'https:\\/\\/blog.naver.com\\/amazonian3?Redirect=Log&logNo=222290843357', 'https:\\/\\/blog.naver.com\\/yamongee?Redirect=Log&logNo=222388430965', 'https:\\/\\/blog.naver.com\\/happysaip?Redirect=Log&logNo=222381854513', 'https:\\/\\/blog.naver.com\\/kyoung8932?Redirect=Log&logNo=222027760028', 'https:\\/\\/blog.naver.com\\/wlgp2711?Redirect=Log&logNo=222495724739', 'https:\\/\\/blog.naver.com\\/fineblue3?Redirect=Log&logNo=222431338285', 'https:\\/\\/blog.naver.com\\/cozy95?Redirect=Log&logNo=222206701087', 'https:\\/\\/blog.naver.com\\/youngpoten?Redirect=Log&logNo=222474577464', 'https:\\/\\/blog.naver.com\\/leonwns?Redirect=Log&logNo=222398040104', 'https:\\/\\/blog.naver.com\\/bo_1203?Redirect=L ...
# 총 링크 수:  100 개

# %%
# 링크를 다듬기 (필요없는 부분 제거 및 수정)
blog_links = []
for i in links:
    a = i.replace('\\','')
    b = a.replace('?Redirect=Log&logNo=','/')
    blog_links.append(b)

print(blog_links)
print('생성된 링크 갯수:',len(blog_links),'개')
# Out:
# ['https://blog.naver.com/lovableje/222508972195', 'https://blog.naver.com/staror7/222541918499', 'https://blog.naver.com/leeih009/222408692869', 'https://blog.naver.com/zhao0201/222019408054', 'https://blog.naver.com/natory77/222098984062', 'https://blog.naver.com/hyuni9987/222217005651', 'https://blog.naver.com/brightenedu/221766379557', 'https://blog.naver.com/daebakyo/222154100950', 'https://blog.naver.com/rostw92/222425036028', 'https://blog.naver.com/wise9140/222531769606', 'https://blog.naver.com/rdal89/222496358947', 'https://blog.naver.com/rladkfk00/222128113098', 'https://blog.naver.com/zenartist55/222358660189', 'https://blog.naver.com/imajinny/222418214924', 'https://blog.naver.com/kizaki56/222114504775', 'https://blog.naver.com/naldapan/222435304959', 'https://blog.naver.com/din_5/222067976377', 'https://blog.naver.com/leonwns/222421609729', 'https://blog.naver.com/cozy95/222005247421', 'https://blog.naver.com/brightenedu/222012653053', 'https://blog.naver.com/hoisulhi/221985197098', 'https://blog.naver.com/alstjs08/222545784322', 'https://blog.naver.com/rostw92/222333493356', 'https://blog.naver.com/wise9140/222474087778', 'https://blog.naver.com/sse0226/222039785528', 'https://blog.naver.com/mulin0913/222511012326', 'https://blog.naver.com/joaran_/221826435369', 'https://blog.naver.com/talesoff/222137392784', 'https://blog.naver.com/cccaaarrrnet/222226529844', 'https://blog.naver.com/nsi1020
        a = driver.find_element_by_css_selector('div.se-main-container').text
        contents.append(a)
    
    except NoSuchElementException:
        a = driver.find_element_by_css_selector('div#content-area').text
        contents.append(a)
    #print(본문: \n', a)




driver.quit() #창닫기
print("<<본문 크롤링이 완료되었습니다.>>")
# Out:
# <<본문 크롤링이 완료되었습니다.>>

# %%
#제목 및 본문 txt에 저장
total_contents = titles + contents

text = open("blog_text.txt",'w',encoding='utf-8') 
for i in total_contents:
    text.write(i)
text.close()

# %%
#제목, 블로그링크, 본문내용 Dataframe으로 만들기
import pandas as pd

df = pd.DataFrame({'제목':titles, '링크':blog_links,'내용':contents})
df
# Out:
#                                               제목  \
# 0                          눈길가는 <b>상암 맛집</b> 리스트
# 1                          감격했던 <b>상암 맛집</b> 리스트
# 2                          흡족했던 <b>상암 맛집</b> 리스트
# 3                          무한흡입 가능한 <b>상암 맛집</b>
# 4                       행복이 가득한 <b>상암 맛집</b> 모음집
# 5                           경이로운 <b>상암 맛집</b> 모음
# 6                              쫄깃했던 <b>상암 맛집</b>
# 7                        감탄이 절로 나오는 <b>상암 맛집</b>
# 8                          훌륭했던 <b>상암 맛집</b> 리스트
# 9  29,000 코스요리 만족! <b>상암</b> 파스타<b>맛집</b> 인칸토 키친
#
#                                                 링크  \
# 0      https://blog.naver.com/staror7/222541918499
# 1    https://blog.naver.com/lovableje/222508972195
# 2     https://blog.naver.com/leeih009/222408692869
# 3     https://blog.naver.com/zhao0201/222019408054
# 4     https://blog.naver.com/natory77/222098984062
# 5    https://blog.naver.com/hyuni9987/222217005651
# 6  https://blog.naver.com/brightenedu/221766379557
# 7     https://blog.naver.com/daebakyo/222154100950
# 8      https://blog.naver.com/rostw92/222425036028
# 9     https://blog.naver.com/wise9140/222531769606
#
#                                                   내용
# 0  며칠 전 대학교 동기들과 마포 쪽에 놀러갔다가 유명한 상암 맛집에 다녀왔어요. 무려...
# 1  며칠 전 남편과 같이 유명한 상암 맛집에 방문했는데요 \n이베리코돼지고기를 부위별로...
# 2  며칠 전, 직장동료들과 유명한 상암 맛집에서 점심식사를 했는데요. 푸짐한 구성의 스...
# 3  며칠 전 친구들과 초밥이 먹고 싶어서 상암 맛집에 찾아갔다.\n무한리필집이라 배불리...
# 4  1.  인기명 상암점\n50m\n© NAVER Corp.\n인기명 상암점\n서울특별...
# 5  오랜만에 마포에 갔다가 점심 먹으러 상암 맛집에 다녀왔어요.\n한약재로 우려낸 조갈...
# 6  Hello, everyone!\n김원장의 탐구생활입니다. \n끝나지 않을 것만 같은...
# 7  하이 하이 괴짜 미녀임>.<ㅋㅋㅋ 며칠 전에 친구들이랑 다녀온 상암 맛집에서 진짜 ...
# 8  저번 주 토요일에 친한 언니와 함께 집 근처인 상암동에 다녀왔다.\n저녁도 먹기로 ...
# 9  #가성비코스요리 #인칸토키친 #상암맛집\n안녕하세요 여러분 수냥입니다 :)\n맛집 ...
